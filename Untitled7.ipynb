# %% [markdown]
# <a href="https://colab.research.google.com/github/Swamini1105/AI-Resume-Screening-System/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ecb563c3-f38e-4aad-b94b-70910aee3285" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecb563c3-f38e-4aad-b94b-70910aee3285">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_path = "archive.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("dataset_folder")

print("Extracted successfully!")
# Out:
# Extracted successfully!

# %%
import os

os.listdir("dataset_folder")
# Out:
# ['Resumes']

# %%
import os

os.listdir("dataset_folder")
# Out:
# ['Resumes']

# %%
import pandas as pd
import os

# See files inside dataset_folder
print(os.listdir("dataset_folder"))
# Out:
# ['Resumes']

# %%
import os

print(os.listdir("dataset_folder"))
# Out:
# ['Resumes']

# %%
import os

print(os.listdir("dataset_folder/Resumes"))
# Out:
# ['Pankaj BSA.docx', 'Krishna Kuruvella.docx', 'Resume_Spoorti Pandit_BSA.docx', 'jeck P.docx', 'Manikanta P.docx', 'Varun Kumar.docx', 'Harika_java.docx', 'Sundar_Java_8+ Years..docx', 'Atul_Mathur_Resume.docx', 'Achyuth Resume_8.docx', 'sairithvik alla.docx', 'Satish Reddy.docx', 'Pierre John.docx', 'MounikaReddy.docx', 'Nikki_Nimmagadd.docx', 'Resume - Kishore Kotapati - 218E - BA.docx', 'Saiteja G.docx', 'Vamshi L.docx', 'ravikiran JALASUTRAPU.docx', 'B Shaker-Sr BSA-Scrum Master .docx', 'manohar.B.docx', 'Naveen Arora.docx', 'Derik.docx', 'Manohar Reddy.docx', 'Priyanka Sr BSA Resume.docx', 'Raja Santhosam_PM Scrum Master.DOCX', 'Shaker Resume.docx', 'mounika BA resume 7.docx', 'Reddemma_Lankipalle.docx', 'Harish K.docx', 'AnilAgarwal.docx', 'Ashok Jayakumar - PM.docx', 'Jennifer  M. Conte.docx', 'Anudeep N_Sr Java Developer.docx', 'Nikith Reddy.docx', 'nithin Reddy.docx', 'BA - Abhishek.docx', 'Vivek.BSA.docx', 'Satish Uduta.docx', 'Samir Naik-NJ - Mar 2018-V3.0.docx', 'Raju God
# ...

# %%
import os

files = os.listdir("dataset_folder/Resumes")

print(files[:5])
# Out:
# ['Pankaj BSA.docx', 'Krishna Kuruvella.docx', 'Resume_Spoorti Pandit_BSA.docx', 'jeck P.docx', 'Manikanta P.docx']

# %%
import os
import pandas as pd

resume_folder = "dataset_folder/Resumes"

data = []

for file in os.listdir(resume_folder):

    file_path = os.path.join(resume_folder, file)

    try:
        with open(file_path, 'r', encoding='utf-8', errors='ignore') as f:
            text = f.read()

        data.append([text, "Unknown"])

    except:
        pass

df = pd.DataFrame(data, columns=["Resume", "Category"])

df.head()
# Out:
#                                               Resume Category
# [Content_Types].xm...  Unknown
# [Content_Types].xml ...  Unknown
# [Content_Types].xml ...  Unknown
# t0I
# _rels/.relsMKA
# ...  Unknown
# [Content_Types].xm...  Unknown

# %%
print(df.shape)
# Out:
# (228, 2)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# ML Pipeline
model = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('clf', MultinomialNB())
])

# Train model
model.fit(df['Resume'], df['Category'])

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
sample_resume = df['Resume'][0]

prediction = model.predict([sample_resume])

print(prediction)
# Out:
# ['Unknown']
